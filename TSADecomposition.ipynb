# %% [markdown]
# # Time Series Decomposition
#
# [Video](https://www.youtube.com/watch?v=pLHm4cvoZiY&list=PL3N9eeOlCrP5cK0QRQxeJd6GrQvhAtpBK&index=5)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
import pandas as pd
import plotly.express as px


mpl.rcParams['figure.figsize'] = (10, 8)
mpl.rcParams['axes.grid'] = False

# %%
def parse(x):
  return datetime.strptime(x, '%m/%d/%Y')

# %%
df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/amazon_revenue_profit.csv', parse_dates = ['Quarter'],date_parser=parse)
df.head()
# Out:
#      Quarter  Revenue  Net Income
# 0 2020-03-31    75452        2535
# 1 2019-12-31    87437        3268
# 2 2019-09-30    69981        2134
# 3 2019-06-30    63404        2625
# 4 2019-03-31    59700        3561

# %%
print ("Rows     : " ,df.shape[0])
print ("Columns  : " ,df.shape[1])
print ("\nFeatures : \n" ,df.columns.tolist())
print ("\nMissing values :  ", df.isnull().any())
print ("\nUnique values :  \n",df.nunique())
# Out:
# Rows     :  61
# Columns  :  3
#
# Features :
#  ['Quarter', 'Revenue', 'Net Income']
#
# Missing values :   Quarter       False
# Revenue       False
# Net Income    False
# dtype: bool
#
# Unique values :
#  Quarter       61
# Revenue       61
# Net Income    57
# dtype: int64

# %%
amazon_df=df.set_index("Quarter")

# %%
amazon_df.head()
# Out:
#             Revenue  Net Income
# Quarter
# 2020-03-31    75452        2535
# 2019-12-31    87437        3268
# 2019-09-30    69981        2134
# 2019-06-30    63404        2625
# 2019-03-31    59700        3561

# %%
amazon_df.plot()
# Out:
# <AxesSubplot: xlabel='Quarter'>

# %%
fig = px.line(df, x='Quarter', y='Revenue', title='Amazon Revenue Slider')

fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(count=2, label="3y", step="year", stepmode="backward"),
            dict(count=3, label="5y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    )
)
fig.show()

# %% [markdown]
# Data is stationary until 2010 then becomes unstationary
#
# **kpss test**
#
# Null hypothesis - data is stationary
#
# Alternate hypothesis = data is not stationary

# %%
from statsmodels.tsa.stattools import kpss

# %%
tstest = kpss(amazon_df['Revenue'], 'ct')
# Out:
# /home/biscotty/anaconda3/envs/pytorch/lib/python3.10/site-packages/statsmodels/tsa/stattools.py:2018: InterpolationWarning:
#
# The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.

# %%
tstest
# Out:
# (0.3066554597516956,
#  0.01,
#  4,
#  {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216})

# %%
import statsmodels.api as sm
res = sm.tsa.seasonal_decompose(amazon_df['Revenue'],
                                model='multiplicative')

resplot = res.plot()

# %% [markdown]
# Why is the time-scale reversed in the graph?

# %%
plt.figure(figsize=(22,7))
res.trend.plot()
# Out:
# <AxesSubplot: xlabel='Quarter'>

# %%
res.observed
# Out:
# Quarter
# 2020-03-31    75452.0
# 2019-12-31    87437.0
# 2019-09-30    69981.0
# 2019-06-30    63404.0
# 2019-03-31    59700.0
#                ...
# 2006-03-31     2279.0
# 2005-12-31     2977.0
# 2005-09-30     1858.0
# 2005-06-30     1753.0
# 2005-03-31     1902.0
# Name: Revenue, Length: 61, dtype: float64

# %%
print(res.trend)
# Out:
# Quarter
# 2020-03-31          NaN
# 2019-12-31          NaN
# 2019-09-30    72099.500
# 2019-06-30    68248.750
# 2019-03-31    64691.375
#                 ...
# 2006-03-31     2369.375
# 2005-12-31     2265.000
# 2005-09-30     2169.625
# 2005-06-30          NaN
# 2005-03-31          NaN
# Name: trend, Length: 61, dtype: float64

# %%
print(res.seasonal)
# Out:
# Quarter
# 2020-03-31    0.941840
# 2019-12-31    1.289518
# 2019-09-30    0.894993
# 2019-06-30    0.873649
# 2019-03-31    0.941840
#                 ...
# 2006-03-31    0.941840
# 2005-12-31    1.289518
# 2005-09-30    0.894993
# 2005-06-30    0.873649
# 2005-03-31    0.941840
# Name: seasonal, Length: 61, dtype: float64

# %%
res.resid
# Out:
# Quarter
# 2020-03-31         NaN
# 2019-12-31         NaN
# 2019-09-30    1.084496
# 2019-06-30    1.063372
# 2019-03-31    0.979831
#                 ...
# 2006-03-31    1.021253
# 2005-12-31    1.019256
# 2005-09-30    0.956844
# 2005-06-30         NaN
# 2005-03-31         NaN
# Name: resid, Length: 61, dtype: float64

# %% [markdown]
# Observed = trend * seasonal * residual

# %%
res.observed[2]
# Out:
# 69981.0

# %%
res.trend[2]*res.seasonal[2]*res.resid[2]
# Out:
# 69980.99999999999

# %% [markdown]
#  We are using a multiplicative model so we can remove the trend by:

# %%
pd.DataFrame(res.observed/res.trend).plot()
# Out:
# <AxesSubplot: xlabel='Quarter'>
